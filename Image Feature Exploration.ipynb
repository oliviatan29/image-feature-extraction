# %% [markdown]
# # ImageIO Exploration

# %%
import imageio
import matplotlib.pyplot as plt

# %% [markdown]
# ## Import Image

# %%
pic = imageio.imread('Documents/Photos/2022 Singapore Sweet Escape/olivia-singapore-s1_11.jpg')
# plt.figure(figsize=(15,15))

plt.imshow(pic)

# %% [markdown]
# ## Basic Image Properties

# %%
print('Type of the image : ',type(pic))

print('Shape of the image : {}'.format(pic.shape))
print('Image Height : {}'.format(pic.shape[0]))
print('Image Width : {}'.format(pic.shape[1]))
megapixels = (pic.shape[0]*pic.shape[1]/1000000)
print('Megapixels : {}'.format(megapixels))

print('Dimension of Image : {}'.format(pic.ndim))
# Out:
# Type of the image :  <class 'imageio.core.util.Array'>
#
# Shape of the image : (4000, 6000, 3)
# Image Hight : 4000
# Image Width : 6000
# Dimension of Image : 3
# Megapixels : 24.0

# %% [markdown]
# ## Image Metadata

# %%
# Metadata of image captured on digital cameras with additional software edits
print(pic.meta.keys())
# Out:
# odict_keys(['exif', 'dpi', 'photoshop', 'adobe', 'adobe_transform', 'icc_profile', 'EXIF_MAIN'])

# %%
print('DPI : ',pic.meta['dpi'])
print('Adobe : ',pic.meta['adobe'])
print('Adobe Transform : ',pic.meta['adobe_transform'])

# print(pic.meta['exif'])
# Out:
# DPI :  (300, 300)
# Adobe :  100
# Adobe Transform :  100

# %%
{**pic.meta['photoshop']}
# Out:
# {1005: {'XResolution': 300.0,
#   'DisplayedUnitsX': 1,
#   'YResolution': 300.0,
#   'DisplayedUnitsY': 1},
#  1028: b'\x1c\x01Z\x00\x03\x1b%G\x1c\x02\x00\x00\x02\x00\x04\x1c\x027\x00\x0820220518\x1c\x02<\x00\x0b170845+0800\x1c\x02>\x00\x0820220518\x1c\x02?\x00\x0b170845+0800\x1c\x02P\x00\x04ALOY\x1c\x02t\x00\x03OWS',
#  1061: b")\xe8\x14\x93*\x0c\x17zC's\xed`\xfc\x8bb"}

# %%
print('ICC Profile : ',pic.meta['icc_profile'])

# https://en.wikipedia.org/wiki/ICC_profile
# Out:
# ICC Profile :  b'\x00\x00\x0cHLino\x02\x10\x00\x00mntrRGB XYZ \x07\xce\x00\x02\x00\t\x00\x06\x001\x00\x00acspMSFT\x00\x00\x00\x00IEC sRGB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf6\xd6\x00\x01\x00\x00\x00\x00\xd3-HP  \x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x11cprt\x00\x00\x01P\x00\x00\x003desc\x00\x00\x01\x84\x00\x00\x00lwtpt\x00\x00\x01\xf0\x00\x00\x00\x14bkpt\x00\x00\x02\x04\x00\x00\x00\x14rXYZ\x00\x00\x02\x18\x00\x00\x00\x14gXYZ\x00\x00\x02,\x00\x00\x00\x14bXYZ\x00\x00\x02@\x00\x00\x00\x14dmnd\x00\x00\x02T\x00\x00\x00pdmdd\x00\x00\x02\xc4\x00\x00\x00\x88vued\x00\x00\x03L\x00\x00\x00\x86view\x00\x00\x03\xd4\x00\x00\x00$lumi\x00\x00\x03\xf8\x00\x00\x00\x14meas\x00\x00\x04\x0c\x00\x00\x00$tech\x00\x00\x040\x00\x00\x00\x0crTRC\x00\x00\x04<\x00\x00\x08\x0cgTRC\x00\x00\x04<\x00\x00\x08\x0cbTRC\x00\x00\x04<\x00\x00\x08\x0cte
# ...

# %%
print('EXIF : ',pic.meta['exif'])

# https://en.wikipedia.org/wiki/Exif
# Out:
# EXIF :  b'Exif\x00\x00II*\x00\x08\x00\x00\x00\n\x00\x0f\x01\x02\x00\n\x00\x00\x00\x86\x00\x00\x00\x10\x01\x02\x00\x06\x00\x00\x00\x90\x00\x00\x00\x1a\x01\x05\x00\x01\x00\x00\x00\x96\x00\x00\x00\x1b\x01\x05\x00\x01\x00\x00\x00\x9e\x00\x00\x00(\x01\x03\x00\x01\x00\x00\x00\x02\x00\x00\x001\x01\x02\x005\x00\x00\x00\xa6\x00\x00\x002\x01\x02\x00\x14\x00\x00\x00\xdc\x00\x00\x00;\x01\x02\x00\x05\x00\x00\x00\xf0\x00\x00\x00\x98\x82\x02\x00\x04\x00\x00\x00OWS\x00i\x87\x04\x00\x01\x00\x00\x00\xf6\x00\x00\x00\x00\x00\x00\x00Panasonic\x00DC-S1\x00,\x01\x00\x00\x01\x00\x00\x00,\x01\x00\x00\x01\x00\x00\x00Adobe Photoshop Lightroom Classic 11.3.1 (Macintosh)\x00\x002022:05:19 13:37:02\x00ALOY\x00\x00(\x00\x9a\x82\x05\x00\x01\x00\x00\x00\xdc\x02\x00\x00\x9d\x82\x05\x00\x01\x00\x00\x00\xe4\x02\x00\x00"\x88\x03\x00\x01\x00\x00\x00\x01\x00\x00\x00\'\x88\x03\x00\x01\x00\x00\x00d\x00\x00\x00\x00\x90\x07\x00\x04\x00\x00\x000231\x03\x90\x02\x00\x14\x00\x00\x00\xec\x02\x00\x00\x04\x90\x02\x00\x14\x00\x00\x00
# ...

# %%
print('Type of the image : ',pic.meta['adobe'])
print('Type of the image : ',pic.meta['adobe_transform'])
# Out:
# Type of the image :  100
# Type of the image :  100

# %%
{**pic.meta['EXIF_MAIN']}

# https://petapixel.com/what-is-exif-data/
# https://exifdata.com/
# Out:
# {'ExifVersion': b'0231',
#  'ShutterSpeedValue': 8.965784,
#  'ApertureValue': 1.695994,
#  'DateTimeOriginal': '2022:05:18 17:08:45',
#  'DateTimeDigitized': '2022:05:18 17:08:45',
#  'ExposureBiasValue': 0.0,
#  'MaxApertureValue': 1.0,
#  'MeteringMode': 2,
#  'LightSource': 0,
#  'Flash': 16,
#  'FocalLength': 35.0,
#  'ColorSpace': 1,
#  'WhiteBalance': 0,
#  'DigitalZoomRatio': 0.0,
#  'FocalPlaneXResolution': 1666.6666564941406,
#  'FocalPlaneYResolution': 1666.6666564941406,
#  36880: '+07:00',
#  36881: '+08:00',
#  36882: '+08:00',
#  'SubsecTimeOriginal': '072',
#  'SubsecTimeDigitized': '072',
#  'FocalPlaneResolutionUnit': 3,
#  'Model': 'DC-S1',
#  'SensingMethod': 2,
#  'Copyright': 'OWS',
#  'FileSource': b'\x03',
#  'ExposureTime': 0.002,
#  'XResolution': 300.0,
#  'YResolution': 300.0,
#  'FNumber': 1.8,
#  'SceneType': b'\x01',
#  'ExposureProgram': 1,
#  'CustomRendered': 0,
#  'ISOSpeedRatings': 100,
#  'ResolutionUnit': 2,
#  'ExposureMode': 1,
# ...

# %% [markdown]
# ## RGB Data

# %%
print('Image size {}'.format(pic.size))

print('Maximum RGB value in this image {}'.format(pic.max()))

print('Minimum RGB value in this image {}'.format(pic.min()))
# Out:
# Image size 72000000
# Maximum RGB value in this image 255
# Minimum RGB value in this image 0

# %%
# A specific pixel located at Row : 100 ; Column : 50 
# Each channel's value of it, gradually R , G , B

print('Value of only R channel {}'.format(pic[ 100, 50, 0]))

print('Value of only G channel {}'.format(pic[ 100, 50, 1]))

print('Value of only B channel {}'.format(pic[ 100, 50, 2]))
# Out:
# Value of only R channel 82
# Value of only G channel 59
# Value of only B channel 5

# %%
plt.title('R channel')

plt.ylabel('Height {}'.format(pic.shape[0]))

plt.xlabel('Width {}'.format(pic.shape[1]))

plt.imshow(pic[ : , : , 0])

plt.show()

# %%
plt.title('G channel')

plt.ylabel('Height {}'.format(pic.shape[0]))

plt.xlabel('Width {}'.format(pic.shape[1]))

plt.imshow(pic[ : , : , 1])

plt.show()

# %%
plt.title('B channel')

plt.ylabel('Height {}'.format(pic.shape[0]))

plt.xlabel('Width {}'.format(pic.shape[1]))

plt.imshow(pic[ : , : , 2])

plt.show()

# %%
# Obtain the red channel
red_channel = pic[:, :, 0]

# Plot the red histogram with bins in a range of 256
plt.hist(red_channel.ravel(), bins=256)

# Set title and show
plt.title('Red Histogram')
plt.show()

# %%
# Obtain the green channel
green_channel = pic[:, :, 1]

# Plot the green histogram with bins in a range of 256
plt.hist(green_channel.ravel(), bins=256)

# Set title and show
plt.title('Green Histogram')
plt.show()

# %%
# Obtain the blue channel
blue_channel = pic[:, :, 2]

# Plot the green histogram with bins in a range of 256
plt.hist(blue_channel.ravel(), bins=256)

# Set title and show
plt.title('Blue Histogram')
plt.show()

# %%
# Combined Histogram

plt.hist(red_channel.ravel(), bins = 256, color = 'red', alpha = 0.5)
plt.hist(green_channel.ravel(), bins = 256, color = 'green', alpha = 0.5)
plt.hist(blue_channel.ravel(), bins = 256, color = 'blue', alpha = 0.5)

plt.xlabel('Intensity Value')
plt.ylabel('Count')
plt.legend(['Red_Channel', 'Green_Channel', 'Blue_Channel'])

plt.title('Combined Histogram')
plt.show()

# %% [markdown]
# # SKImage Model Features

# %%
import skimage

# %%
def show_image(image, title='Image', cmap_type='gray'):
    plt.imshow(image, cmap=cmap_type)
    plt.title(title)
    plt.axis('off')
    plt.show()

# %%
from skimage import data, color

gray_pic = color.rgb2gray(pic)

# %%
ax = plt.hist(gray_pic.ravel(), bins = 256)
plt.title('Gray Histogram')
plt.xlabel('Intensity Value')
plt.ylabel('Count')
plt.show()

# %%
# from skimage import io
# pic = io.imread('Documents/Photos/2022 Singapore Sweet Escape/olivia-singapore-s1_11.jpg')

# %%
# Import the color module
from skimage import data, color

# Import the filters module and sobel function
from skimage.filters import sobel

# Make the image grayscale
soaps_image = pic
soaps_image_gray = color.rgb2gray(soaps_image)

# Apply edge detection filter
edge_sobel = sobel(soaps_image_gray)

# Show original and resulting image to compare
show_image(soaps_image, "Original")
show_image(edge_sobel, "Edges with Sobel")

# %%
# Import the required module
from skimage import exposure

# Use histogram equalization to improve the contrast
image_eq =  exposure.equalize_hist(soaps_image_gray)

# Show the original and resulting image
show_image(soaps_image_gray, 'Original')
show_image(image_eq, 'Resulting image')

# %%
# Apply edge detection filter
edge_sobel2 = sobel(image_eq)

# Show original and resulting image to compare
show_image(edge_sobel, "Original")
show_image(edge_sobel2, "Edges with Sobel")

# %%
from matplotlib import patches

def show_detected_face(result, detected, title="Face image"):
    plt.imshow(result)
    img_desc = plt.gca()
    plt.set_cmap('gray')
    plt.title(title)
    plt.axis('off')
    
    for patch in detected:
        img_desc.add_patch(
            patches.Rectangle(
                (patch['c'], patch['r']),
                patch['width'],
                patch['height'],
                fill=False,color='r'
                ,linewidth=2)
        )
    plt.show()

# %%
from skimage.feature import Cascade

# Load the trained file from data
trained_file = data.lbp_frontal_face_cascade_filename()

# Initialize the detector cascade
detector = Cascade(trained_file)

# Detect faces with min and max size of searching window
detected = detector.detect_multi_scale(img = pic,
                                       scale_factor=1.2,
                                       step_ratio=1,
                                       min_size=(60,60),
                                       max_size=(200,200))

# Show the detected faces
show_detected_face(pic, detected)

# %%
detected
# Out:
# [{'r': 284, 'c': 989, 'width': 121, 'height': 121},
#  {'r': 723, 'c': 5215, 'width': 115, 'height': 115},
#  {'r': 1931, 'c': 298, 'width': 106, 'height': 106},
#  {'r': 2601, 'c': 3924, 'width': 87, 'height': 87},
#  {'r': 3378, 'c': 248, 'width': 97, 'height': 97}]

# %% [markdown]
# ### Dominant Colors

# %%
import pandas as pd
from scipy.cluster.vq import whiten
  
# Store RGB values of all pixels in lists r, g and b
r = []
g = []
b = []
for row in pic:
    for temp_r, temp_g, temp_b in row:
        r.append(temp_r)
        g.append(temp_g)
        b.append(temp_b)
  
# only printing the size of these lists
# as the content is too big
print(len(r))
print(len(g))
print(len(b))
  
# Saving as DataFrame
batman_df = pd.DataFrame({'red' : r,
                          'green' : g,
                          'blue' : b})
  
# Scaling the values
batman_df['scaled_color_red'] = whiten(batman_df['red'])
batman_df['scaled_color_blue'] = whiten(batman_df['blue'])
batman_df['scaled_color_green'] = whiten(batman_df['green'])
# Out:
# 24000000
# 24000000
# 24000000

# %%
from scipy.cluster.vq import kmeans
import pandas as pd
import seaborn as sns

distortions = []
num_clusters = range(1, 7)  #range of cluster sizes
  
# Create a list of distortions from the kmeans function
for i in num_clusters:
    cluster_centers, distortion = kmeans(batman_df[['scaled_color_red', 
                                                    'scaled_color_blue', 
                                                    'scaled_color_green']], i)
    distortions.append(distortion)
      
# Create a data frame with two lists, num_clusters and distortions
elbow_plot = pd.DataFrame({'num_clusters' : num_clusters,
                           'distortions' : distortions})
  
# Create a line plot of num_clusters and distortions
sns.lineplot(x = 'num_clusters', y = 'distortions', data = elbow_plot)
plt.xticks(num_clusters)
plt.show()

# %%
cluster_centers, _ = kmeans(batman_df[['scaled_color_red',
                                       'scaled_color_blue',
                                       'scaled_color_green']], 5)
  
dominant_colors = []
  
# Get standard deviations of each color
red_std, green_std, blue_std = batman_df[['red',
                                          
                                          'green',
                                          'blue']].std()
  
for cluster_center in cluster_centers:
    red_scaled, green_scaled, blue_scaled = cluster_center
  
    # Convert each standardized value to scaled value
    dominant_colors.append((
        red_scaled * red_std / 255,
        green_scaled * green_std / 255,
        blue_scaled * blue_std / 255
    ))
  
# Display colors of cluster centers
plt.imshow([dominant_colors])
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Analyzing other Images

# %% [markdown]
# ## Photo from smartphone

# %%
pic2 = imageio.imread('Downloads/PXL_20220205_070740230.MP.jpg')
# plt.figure(figsize=(15,15))

plt.imshow(pic2)

# %%
# Metadata of image captured on smartphone
print(pic2.meta.keys())
# Out:
# odict_keys(['exif', 'dpi', 'jfif', 'jfif_version', 'jfif_unit', 'jfif_density', 'icc_profile', 'EXIF_MAIN'])

# %%
{**pic2.meta['EXIF_MAIN']}
# Out:
# {'ExifVersion': b'0232',
#  'ComponentsConfiguration': b'\x01\x02\x03\x00',
#  'ShutterSpeedValue': 10.2,
#  'DateTimeOriginal': '2022:02:05 15:07:40',
#  'DateTimeDigitized': '2022:02:05 15:07:40',
#  'ApertureValue': 1.58,
#  'BrightnessValue': 7.84,
#  'ExposureBiasValue': 0.0,
#  'MaxApertureValue': 1.58,
#  'SubjectDistance': 4294967295.0,
#  'MeteringMode': 2,
#  'Flash': 16,
#  'FocalLength': 4.38,
#  'ColorSpace': 1,
#  'ExifImageWidth': 4032,
#  'SceneCaptureType': 0,
#  36880: '+08:00',
#  36881: '+08:00',
#  36882: '+08:00',
#  'SubsecTime': '230',
#  'SubsecTimeOriginal': '230',
#  'SubsecTimeDigitized': '230',
#  'ExifImageHeight': 3024,
#  'SensingMethod': 2,
#  'Make': 'Google',
#  'Model': 'Pixel 4',
#  'ExposureTime': 0.000852,
#  'ExifInteroperabilityOffset': 946,
#  'XResolution': 72.0,
#  'FNumber': 1.73,
#  'SceneType': b'\x01',
#  'YResolution': 72.0,
#  'ExposureProgram': 2,
#  'GPSInfo': {1: 'N',
#   2: (1.0, 16.0, 59.99),
#   3: 'E',
# ...

# %%
# Combined Histogram

plt.hist(pic2[:, :, 0].ravel(), bins = 256, color = 'red', alpha = 0.5)
plt.hist(pic2[:, :, 1].ravel(), bins = 256, color = 'green', alpha = 0.5)
plt.hist(pic2[:, :, 2].ravel(), bins = 256, color = 'blue', alpha = 0.5)

plt.xlabel('Intensity Value')
plt.ylabel('Count')
plt.legend(['Red_Channel', 'Green_Channel', 'Blue_Channel'])

plt.title('Combined Histogram')
plt.show()

# %%
# Detect faces with min and max size of searching window
detected = detector.detect_multi_scale(img = pic2,
                                       scale_factor=1.2,
                                       step_ratio=1,
                                       min_size=(60,60),
                                       max_size=(200,200))

# Show the detected faces
show_detected_face(pic2, detected)

# %%
# Store RGB values of all pixels in lists r, g and b
r = []
g = []
b = []
for row in pic2:
    for temp_r, temp_g, temp_b in row:
        r.append(temp_r)
        g.append(temp_g)
        b.append(temp_b)
  
# only printing the size of these lists
# as the content is too big
print(len(r))
print(len(g))
print(len(b))
  
# Saving as DataFrame
batman_df = pd.DataFrame({'red' : r,
                          'green' : g,
                          'blue' : b})
  
# Scaling the values
batman_df['scaled_color_red'] = whiten(batman_df['red'])
batman_df['scaled_color_blue'] = whiten(batman_df['blue'])
batman_df['scaled_color_green'] = whiten(batman_df['green'])
# Out:
# 12192768
# 12192768
# 12192768

# %%
distortions = []
num_clusters = range(1, 10)  #range of cluster sizes
  
# Create a list of distortions from the kmeans function
for i in num_clusters:
    cluster_centers, distortion = kmeans(batman_df[['scaled_color_red', 
                                                    'scaled_color_blue', 
                                                    'scaled_color_green']], i)
    distortions.append(distortion)
      
# Create a data frame with two lists, num_clusters and distortions
elbow_plot = pd.DataFrame({'num_clusters' : num_clusters,
                           'distortions' : distortions})
  
# Create a line plot of num_clusters and distortions
sns.lineplot(x = 'num_clusters', y = 'distortions', data = elbow_plot)
plt.xticks(num_clusters)
plt.show()

# %%
cluster_centers, _ = kmeans(batman_df[['scaled_color_red',
                                       'scaled_color_blue',
                                       'scaled_color_green']], 5)
  
dominant_colors = []
  
# Get standard deviations of each color
red_std, green_std, blue_std = batman_df[['red',
                                          'green',
                                          'blue']].std()
  
for cluster_center in cluster_centers:
    red_scaled, green_scaled, blue_scaled = cluster_center
  
    # Convert each standardized value to scaled value
    dominant_colors.append((
        red_scaled * red_std / 255,
        green_scaled * green_std / 255,
        blue_scaled * blue_std / 255
    ))
  
# Display colors of cluster centers
plt.imshow([dominant_colors])
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Laptop Screenshot

# %%
pic3 = imageio.imread('Desktop/Screenshot 2022-09-11 at 1.57.00 PM.png')
# plt.figure(figsize=(15,15))

plt.imshow(pic)

# %%
print(pic3.meta.keys())
# Out:
# odict_keys(['icc_profile', 'exif', 'XML:com.adobe.xmp'])

# %%
pic3.meta['exif']
# Out:
# b'Exif\x00\x00MM\x00*\x00\x00\x00\x08\x00\x01\x87i\x00\x04\x00\x00\x00\x01\x00\x00\x00\x1a\x00\x00\x00\x00\x00\x03\x92\x86\x00\x07\x00\x00\x00\x12\x00\x00\x00D\xa0\x02\x00\x04\x00\x00\x00\x01\x00\x00\x04\\\xa0\x03\x00\x04\x00\x00\x00\x01\x00\x00\x02\xed\x00\x00\x00\x00ASCII\x00\x00\x00Screenshot'

# %%
pic3.meta['icc_profile']
# Out:
# b'\x00\x00\x02\x10appl\x04\x00\x00\x00mntrRGB XYZ \x07\xe6\x00\t\x00\x0b\x00\x0c\x00\x0e\x00\x0cacspAPPL\x00\x00\x00\x00APPL\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf6\xd6\x00\x01\x00\x00\x00\x00\xd3-appl/\x97\xef\xa4\x10V\xbd\xd0\x81\xa2(,\x89\xa0D\xf9\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\ndesc\x00\x00\x00\xfc\x00\x00\x00bcprt\x00\x00\x01`\x00\x00\x00#wtpt\x00\x00\x01\x84\x00\x00\x00\x14rXYZ\x00\x00\x01\x98\x00\x00\x00\x14gXYZ\x00\x00\x01\xac\x00\x00\x00\x14bXYZ\x00\x00\x01\xc0\x00\x00\x00\x14rTRC\x00\x00\x01\xd4\x00\x00\x00\x10chad\x00\x00\x01\xe4\x00\x00\x00,bTRC\x00\x00\x01\xd4\x00\x00\x00\x10gTRC\x00\x00\x01\xd4\x00\x00\x00\x10desc\x00\x00\x00\x00\x00\x00\x00\x08P27h-20\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x0
# ...

# %%
pic3.meta['XML:com.adobe.xmp']
# Out:
# '<x:xmpmeta xmlns:x="adobe:ns:meta/" x:xmptk="XMP Core 6.0.0">\n   <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">\n      <rdf:Description rdf:about=""\n            xmlns:exif="http://ns.adobe.com/exif/1.0/">\n         <exif:PixelYDimension>749</exif:PixelYDimension>\n         <exif:PixelXDimension>1116</exif:PixelXDimension>\n         <exif:UserComment>Screenshot</exif:UserComment>\n      </rdf:Description>\n   </rdf:RDF>\n</x:xmpmeta>\n'

# %%
# Combined Histogram

plt.hist(pic3[:, :, 0].ravel(), bins = 256, color = 'red', alpha = 0.5)
plt.hist(pic3[:, :, 1].ravel(), bins = 256, color = 'green', alpha = 0.5)
plt.hist(pic3[:, :, 2].ravel(), bins = 256, color = 'blue', alpha = 0.5)

plt.xlabel('Intensity Value')
plt.ylabel('Count')
plt.legend(['Red_Channel', 'Green_Channel', 'Blue_Channel'])

plt.title('Combined Histogram')
plt.show()
